# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt #if using matplotlib
import geopandas as gpd
import plotly.express as px
import pyproj
import json
import imageio

# %%
fp = "../Data/StateShapeFiles/historicalstates/US_HistStateTerr_Gen001.shx"
#fp = "../Data/StateShapeFiles/historicalcounties_1790/US_HistCounties_Gen01.shx"
map_df = gpd.read_file(fp)
map_df.to_crs(pyproj.CRS.from_epsg(4326), inplace=True)

# %%
map_df = map_df[map_df['CITATION'].apply(lambda x: 'declaration of independence' in x.lower())]

# %%
fig, ax = plt.subplots(1, 1)
map_df.plot(figsize=(800, 300), ax = ax)
plt.show()

# %%
with open('state_abbrev.json') as json_file:
    us_state_to_abbrev = json.load(json_file)

# %%
map_df['STATE'] = map_df['NAME'].apply(lambda x: us_state_to_abbrev[x])

# %%
debt_data = pd.read_csv("statewise_all_assets_rep.csv", index_col = 0)

# %%
df_merged = map_df.merge(debt_data, left_on=['STATE'], right_on=['state'])

# %%
df_merged.fillna(0, inplace = True)

# %%
df_merged
# Out:
#     ID_NUM            NAME        ID  VERSION  START_DATE    END_DATE  \
# 0       22     Connecticut  ct_state        1  1783-09-03  1786-09-13
# 1       28        Delaware  de_state        1  1783-09-03  2000-12-31
# 2       42         Georgia  ga_state        1  1783-09-03  1798-04-06
# 3       76   Massachusetts  ma_state        1  1783-09-03  1804-12-30
# 4       81        Maryland  md_state        1  1783-09-03  1791-03-29
# 5      116  North Carolina  nc_state        1  1783-09-03  1790-04-01
# 6      128   New Hampshire  nh_state        1  1783-09-03  2000-12-31
# 7      129      New Jersey  nj_state        1  1783-09-03  2000-12-31
# 8      143        New York  ny_state        1  1783-09-03  1855-01-10
# 9      143        New York  ny_state        1  1783-09-03  1855-01-10
# 10     155    Pennsylvania  pa_state        1  1783-09-03  1792-03-02
# 11     157    Rhode Island  ri_state        1  1783-09-03  1862-02-28
# 12     159  South Carolina  sc_state        1  1783-09-03  2000-12-31
# 13     195        Virginia  va_state        1  1783-09-03  1784-02-29
#
#                                                CHANGE  \
# 0   Connecticut became an independent state on 4 J...
# 1   The three Lower Counties, of KENT, NEW CASTLE,...
# 2   Georgia became an independent state on 4 July ...
# 3   Massachusetts, including the area of Maine, be...
# 4   Maryland became an independent state on 4 July...
# 5   North Carolina became an independent state on ...
# 6   New Hampshire became an independent state on 4...
# 7   New Jersey became an independent state on 4 Ju...
# 8   New York became an independent state on 4 July...
# 9   New York became an independent state on 4 July...
# 10  Pennsylvania became an independent state on 4 ...
# 11  Rhode Island became an independent state on 4 ...
# 12  South Carolina became an independent state on ...
# 13  Virginia became an independent state on 4 July...
#
#                                           CITATION   START_N     END_N  ...  \
# 0                    (Declaration of Independence)  17830903  17860913  ...
# 1   (Declaration of Independence; Swindler, 2:197)  17830903  20001231  ...
# 2                    (Declaration of Independence)  17830903  17980406  ...
# 3                    (Declaration of Independence)  17830903  18041230  ...
# 4                    (Declaration of Independence)  17830903  17910329  ...
# 5                    (Declaration of Independence)  17830903  17900401  ...
# 6                    (Declaration of Independence)  17830903  20001231  ...
# 7                    (Declaration of Independence)  17830903  20001231  ...
# 8                    (Declaration of Independence)  17830903  18550110  ...
# 9                    (Declaration of Independence)  17830903  18550110  ...
# 10                   (Declaration of Independence)  17830903  17920302  ...
# 11                   (Declaration of Independence)  17830903  18620228  ...
# 12                   (Declaration of Independence)  17830903  20001231  ...
# 13                   (Declaration of Independence)  17830903  17840229  ...
#
#     State Liquidated pct Pierce pct CD pct ASD pct pre1790 total (pop adj)  \
# 0                   0.02       0.14   0.12    0.09                   13.86
# 1                   0.02       0.02   0.00    0.00                    9.40
# 2                   0.00       0.01   0.00    0.00                    3.99
# 3                   0.05       0.27   0.01    0.01                   21.52
# 4                   0.00       0.07   0.13    0.04                    4.71
# 5                   0.00       0.04   0.00    0.01                    1.67
# 6                   0.00       0.05   0.02    0.00                   11.13
# 7                   0.21       0.06   0.00    0.00                   24.97
# 8                   0.42       0.09   0.00    0.11                   32.82
# 9                   0.00       0.00   0.17    0.44                    0.00
# 10                  0.26       0.14   0.25    0.04                   29.93
# 11                  0.02       0.01   0.07    0.02                    4.54
# 12                  0.00       0.00   0.13    0.14                    0.00
# 13                  0.00       0.08   0.08    0.09                    1.99
#
#    post1790 total (pop adj) pre1790 pct (pop adj) post1790 pct (pop adj)  \
# 0                      8.86                  8.64                   9.75
# 1                      0.36                  5.85                   0.40
# 2                      0.39                  2.48                   0.43
# 3                      0.65                 13.40                   0.72
# 4                      7.79                  2.94                   8.57
# 5                      0.36                  1.04                   0.40
# 6                      4.38                  6.93                   4.82
# 7                      0.38                 15.56                   0.42
# 8                      2.33                 20.45                   2.57
# 9                     20.47                  0.00                  22.53
# 10                    12.38                 18.64                  13.63
# 11                    14.25                  2.83                  15.68
# 12                    15.67                  0.00                  17.24
# 13                     2.60                  1.24                   2.86
#
#     total asset dif (pop adj)  total asset pct dif (pop adj)
# 0                       -5.00                           1.11
# 1                       -9.04                          -5.46
# 2                       -3.60                          -2.05
# 3                      -20.86                         -12.68
# 4                        3.08                           5.64
# 5                       -1.31                          -0.64
# 6                       -6.74                          -2.11
# 7                      -24.59                         -15.14
# 8                      -30.49                         -17.88
# 9                       20.47                          22.53
# 10                     -17.54                          -5.02
# 11                       9.71                          12.85
# 12                      15.67                          17.24
# 13                       0.61                           1.62
#
# [14 rows x 42 columns]

# %%
df_merged.columns
# Out:
# Index(['ID_NUM', 'NAME', 'ID', 'VERSION', 'START_DATE', 'END_DATE', 'CHANGE',
#        'CITATION', 'START_N', 'END_N', 'AREA_SQMI', 'TERR_TYPE', 'FULL_NAME',
#        'ABBR_NAME', 'NAME_START', 'geometry', 'STATE', 'state',
#        'Loan Office Certificates Specie Value',
#        'State Liquidated Debt Dollars', 'Pierce Certificates Value',
#        'pre1790 total', 'ASD Total', 'CD Total', 'post1790 total', 'pop',
#        'pre1790 pct', 'post1790 pct', 'total asset dif',
#        'total asset dif (adj)', 'total asset pct dif', 'Loan Office pct',
#        'State Liquidated pct', 'Pierce pct', 'CD pct', 'ASD pct',
#        'pre1790 total (pop adj)', 'post1790 total (pop adj)',
#        'pre1790 pct (pop adj)', 'post1790 pct (pop adj)',
#        'total asset dif (pop adj)', 'total asset pct dif (pop adj)'],
#       dtype='object')

# %%
fig2, ax2 = plt.subplots(1, figsize = (40, 20))
fig = df_merged.plot(column='Loan Office Certificates Specie Value', linewidth=1, ax=ax2, edgecolor='0.9', legend = True)
plt.tight_layout()
